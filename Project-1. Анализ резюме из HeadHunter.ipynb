# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
df = pd.read_csv('data\dst-3.0_16_1_hh_database.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
df.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
df['Образование'] = df['Образование и ВУЗ'].apply(lambda x: x[:x.find('образование')].strip().lower())
df.drop('Образование и ВУЗ',axis=1,inplace=True)
mid_edu = df[df['Образование']=='среднее']['Образование'].count()
print(f'Cоискателей, имеющих средний уровень образования (школьное образование): {mid_edu}')
# Out:
# Cоискателей, имеющих средний уровень образования (школьное образование): 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
df['Пол'] = df['Пол, возраст'].apply(lambda x: x.split(',')[0][0])
df['Возраст'] = df['Пол, возраст'].apply(lambda x: int(x.split(',')[1].strip().split(' ')[0]))
df.drop('Пол, возраст',axis=1,inplace=True)
w_percent = 100*df[df['Пол']=='Ж']['Пол'].count() / df.shape[0]
print(f'Процент женских резюме: {w_percent:.2f}')
print(f'Cредний возраст соискателей: {df['Возраст'].mean():.1f}')
# Out:
# Процент женских резюме: 19.07
# Cредний возраст соискателей: 32.2

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def job_exp(data):
    year = ['год','года','лет']
    month = ['месяц','месяца','месяцев']
    if data==None or data=='Не указано' or isinstance(data,float):
        return None
    else:
        job_ = data.split(' ')[2:6]
        if job_[1] in year:
            job_exp = int(job_[0]) * 12
            if job_[3] in month:
                job_exp += int(job_[2])
        elif job_[1] in month:
                job_exp = int(job_[0])
        return  job_exp  
df['Опыт работы (месяц)'] = df['Опыт работы'].apply(job_exp)
df.drop('Опыт работы',axis=1,inplace=True)
print(f'Медианный опыт работы (в месяцах): {df['Опыт работы (месяц)'].median()}')
# Out:
# Медианный опыт работы (в месяцах): 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]
df['Город'] = df['Город, переезд, командировки'].apply(
    lambda x: x.split(",")[0].strip() if x.split(",")[0].strip()=="Москва" or x.split(",")[0].strip()=="Санкт-Петербург" 
            else 'город-миллионник' if x.split(",")[0].strip() in million_cities 
            else 'другие'
)
spb_count = 100*df[df['Город']=='Санкт-Петербург']['Город'].count() / df['Город'].shape[0]
df['Готовность к переезду'] = df['Город, переезд, командировки'].apply(
	lambda x: False if 'не готов к переезду' in str(x).lower() or
					   'не готова к переезду' in str(x).lower() or
                        'не хочу переехать' in str(x).lower()
	else True if 'готов к переезду' in str(x).lower() or
				 'готова к переезду' in str(x).lower() or
				 'хочу переехать' in str(x).lower()
	else False
)
df['Готовность к командировкам'] = df['Город, переезд, командировки'].apply(
	lambda x: False if 'не готова к командировкам' in str(x).lower() or
					   'не готов к командировкам' in str(x).lower()
	else True if 'готова к командировкам' in str(x).lower() or
				 'готов к командировкам' in str(x).lower() or
				 'готов к редким командировкам' in str(x).lower() or
                 'готова к редким командировкам' in str(x).lower()
	else False
)
df.drop('Город, переезд, командировки',axis=1,inplace=True)
bt_and_rmvl = 100*df[(df['Готовность к переезду']==True)&(df['Готовность к командировкам']==True)]['Готовность к переезду'].count() / df['Готовность к переезду'].shape[0]
print(f'Процент соискателей, живущих в Санкт-Петербурге: {spb_count:.0f}')
print(f'Процент соискателей, готовых одновременно и к переездам, и к командировкам: {bt_and_rmvl:.0f}')
# Out:
# Процент соискателей, живущих в Санкт-Петербурге: 11
# Процент соискателей, готовых одновременно и к переездам, и к командировкам: 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
busyness = ['полная занятость','частичная занятость','проектная работа','волонтерство','стажировка']
for busy in busyness:
    df[busy] = df['Занятость'].apply(lambda x: busy in x.lower())
val1 = df[(df['волонтерство']==True) & (df['проектная работа']==True)]['волонтерство'].count()
schedules = ['полный день','сменный график','гибкий график','удаленная работа','вахтовый метод']
for schedule in schedules:
    df[schedule] = df['График'].apply(lambda x: schedule in x.lower())
val2 = df[(df['вахтовый метод']==True) & (df['гибкий график']==True)]['вахтовый метод'].count()
df.drop('Занятость',axis=1,inplace=True)
df.drop('График',axis=1,inplace=True)

print(f'Людей, желающих проектную работу и волонтерство: {val1}')
print(f'Людей, желающих работать вахтовым методом и с гибким графиком: {val2}')
# Out:
# Людей, желающих проектную работу и волонтерство: 436
# Людей, желающих работать вахтовым методом и с гибким графиком: 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
er = pd.read_csv('data\ExchangeRates.csv', sep=',')
er.drop(['per','time','vol'],axis=1,inplace=True)
df['Обновление резюме'] = pd.to_datetime(df['Обновление резюме'],dayfirst=True).dt.date
er['date'] = pd.to_datetime(er['date'], format='%d/%m/%y').dt.date
currency_dict = {
    'грн': 'UAH',
    'USD': 'USD',
    'EUR': 'EUR',
    'бел.руб': 'BYN',
    'KGS': 'KGS',
    'сум': 'UZS',
    'AZN': 'AZN',
    'KZT': 'KZT',
    'руб': 'RUB'
}
df['ЗП валюта'] = df['ЗП'].apply(lambda x: currency_dict[x.split(' ')[1].strip('.').strip()])
df = df.merge(er,left_on=['ЗП валюта','Обновление резюме'],right_on=['currency','date'],how='left')
df.fillna({'close':1},inplace=True)
df.fillna({'proportion':1},inplace=True)
df['ЗП (руб)'] = df.apply(lambda x: int(x.ЗП.split(' ')[0]) * x.close / int(x.proportion), axis=1)
print(f'Медиана заработной платы по выгрузке: {df['ЗП (руб)'].median()}')
df.drop(['ЗП','ЗП валюта','currency','date','close','proportion'],axis=1,inplace=True)
# Out:
# Медиана заработной платы по выгрузке: 59019.0

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig1 = make_subplots(rows=2, cols=1,
    subplot_titles=('Распределение количества резюме от возраста соискателей', 
                    'Диаграмма Тьюки для возраста соискателей'),
    vertical_spacing=0.1,
    row_heights=[0.5, 0.5]
                )
fig1.add_trace(go.Histogram(x=df["Возраст"], nbinsx=50),
              row=1, col=1)

fig1.add_trace(go.Box(y=df["Возраст"], marker_color='crimson'), row=2, col=1)

fig1.update_layout(  
    showlegend=False,
    height=1000,
    width=1000,
)

fig1.update_xaxes(title_text="Возраст", row=1, col=1)
fig1.update_yaxes(title_text="Количество поданных резюме", row=1, col=1)
fig1.update_xaxes(tickvals=[0, 1], ticktext=['Все резюме'], row=2, col=1)
fig1.update_yaxes(title_text="Возраст", row=2, col=1)
fig1.show()

# %% [markdown]
# Если посмотреть на приведенную гистограмму распределения, то видно, что мода лежит в интервале от 28 лет до 31 года (статистически, это 30 лет). Предельные значения можно оценить на концах гистограммы: минимальный возраст - 14 лет, максимальный - 100 лет. Примерный интервал возраста большинства соискателей можно оценить по диаграмме Тьюки и он составляет от 27 до 35 лет (самое трудоспособное и при этом активное население). Так же из диаграммы Тьюки можно видеть аномальный выброс соискателя с возрастом 100 лет. Анализ данной записи указывает на ошибку в данных (опыт работы менее 3х лет, стажировка). Данная строка подлежит удалению.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig2 = make_subplots(rows=2, cols=1,
    subplot_titles=('Распределение количества резюме от опыта работы соискателей в месяцах', 
                    'Диаграмма Тьюки для опыта работы соискателей (мес.)'),
    vertical_spacing=0.1,
    row_heights=[0.5, 0.5]
                )
fig2.add_trace(go.Histogram(x=df['Опыт работы (месяц)'], nbinsx=50),
              row=1, col=1)

fig2.add_trace(go.Box(y=df['Опыт работы (месяц)'], marker_color='crimson'), row=2, col=1)

fig2.update_layout(  
    showlegend=False,
    height=1000,
    width=1000,
)

fig2.update_xaxes(title_text='Опыт работы (месяц)', row=1, col=1)
fig2.update_yaxes(title_text="Количество поданных резюме", row=1, col=1)
fig2.update_xaxes(tickvals=[0, 1], ticktext=['Все резюме'], row=2, col=1)
fig2.update_yaxes(title_text='Опыт работы (месяц)', row=2, col=1)
fig2.show()

# %% [markdown]
# По приведенной гистограмме видно, что мода лежит в интервале 50 - 99 месяцев (точное значение 81 месяц). Предельные значения можно оценить на концах гистограммы: минимальный стаж - 0 месяцев (без опыта работы), максимальный - 1188 месяцев.
# Распределение похоже на логнормальное, поэтому применение диаграммы Тьюки может дать несколько искаженный результат.
# По коробчатой диаграмме видно, что опыт работы большинства соискателей находится в пределах от 57 до 154 месяцев.
# Так же из диаграммы Тьюки можно видеть аномальный выброс соискателя с опытом работы 99 лет. Анализ данной записи указывает на ошибку в данных (возраст 48 лет). Данная строка подлежит удалению. При анализе других значений выше 600 месяцев аномалий не выявлено.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %% [markdown]
# Для увеличения читаемости гистограммы, ограничимся рассмотрением ЗП до 1 млн. руб. Для оценки выбросов на коробчатой диаграмме модификаций вносить не будем.

# %%
fig3 = make_subplots(rows=2, cols=1,
    subplot_titles=('Распределение количества резюме от желаемой заработной платы (руб.)', 
                    'Диаграмма Тьюки для желаемой заработной платы (руб.)'),
    vertical_spacing=0.1,
    row_heights=[0.5, 0.5]
                )
fig3.add_trace(go.Histogram(x=df[df['ЗП (руб)']<1000000]['ЗП (руб)'], nbinsx=50),
              row=1, col=1)

fig3.add_trace(go.Box(y=df['ЗП (руб)'], marker_color='crimson'), row=2, col=1)

fig3.update_layout(  
    showlegend=False,
    height=1000,
    width=1000,
)

fig3.update_xaxes(title_text='ЗП (руб)', row=1, col=1)
fig3.update_yaxes(title_text="Количество поданных резюме", row=1, col=1)
fig3.update_xaxes(tickvals=[0, 1], ticktext=['Все резюме'], row=2, col=1)
fig3.update_yaxes(title_text='ЗП (руб)', row=2, col=1)
fig3.show()

# %% [markdown]
# Мода распределения желаемой зарплаты лежит в интервале 40-60 тыс.руб, строго математически 50 тыс.руб.
# Сам признак желаемой ЗП принимает значения практически от 0 до 25 млн.руб в месяц. Желаемая заработная плата большинства соискателей находится в диапазоне 37-95тыс.руб.
# Всего в данных имеется 5 соискателей с желаемой зарплатой более 1 млн.руб.
# Значения 24304876.0 и 7675224.0 руб. - потенциальные выбросы, из анализа последней занимаемой должности и стажа, кандидаты не могут претендовать на такие зарплаты. Если проверить исходные данные, можно предположить что зарплата указана на американский манер (за год, а не за месяц).

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
fig4 = px.bar(
    data_frame=df[df['ЗП (руб)']<1000000].groupby('Образование', as_index=False).agg({'ЗП (руб)':'median',}), 
    x="Образование", 
    y="ЗП (руб)", 
    color="Образование",
    labels={'ЗП (руб)': 'Медианная ЗП(руб)', 
            'Образование': 'Уровень образования'},
    orientation='v',
    height=500, 
    width=1000, 
    title='Медианная желаемая зарплата в разрезе образования соискателей'
)

fig4.update_layout(
    showlegend=False,
    title_x=0.5,
    font_size=14,
    title_font_size=20
)

fig4.show()

# %% [markdown]
# Из диаграммы видно, что наибольшая медианная желаемая заработная плата свойственна людям с высшим образованием. В целом график показывает падение медианной желаемой зарплаты с падением уровня образования. Это связано, в т.ч. и с тем, что более образованные работники могут выполнять более сложную работу, что неизбежно ведет к росту зарплаты относительно менее квалифицированной работы. Таким образом, уровень образования можно считать значимым признаком при прогнозировании желаемой зарплаты.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
fig5 = make_subplots(rows=2, cols=1,
    subplot_titles=('Медианная зарплата (среди значений <1млн.руб.) в разрезе города проживания соискателей', 
                    'Диаграмма Тьюки для зарплат (среди значений <1млн.руб.) в разрезе города проживания соискателей'),
    vertical_spacing=0.1,
    row_heights=[0.5, 0.5]
                )
data = df[(df['ЗП (руб)']<1000000)].groupby('Город',as_index=False).agg({'ЗП (руб)':'median',})

fig5.add_trace(go.Bar(
    y=data['ЗП (руб)'], 
    x=data['Город'],
    marker_color=['#ff6633', '#6cb3ff','#aa7755','#ee1155'],
    #labels={'ЗП (руб)': 'Медианная ЗП(руб)', 
    #        'Город': 'Город проживания'},
),
              row=1, col=1)

color={'Москва':'#ff6633', 'Санкт-Петербург':'#6cb3ff','город-миллионник':'#aa7755','другие':'#ee1155'}
for town in ['Москва', 'Санкт-Петербург','город-миллионник','другие']:
    data = df[(df['ЗП (руб)']<1000000)&(df['Город']==town)]
    fig5.add_trace(go.Box(
    y=data['ЗП (руб)'],
    #x=['Москва','Санкт-Петербург','город-миллионник','другие'], 
    marker_color=color[town]), 
               row=2, col=1)

fig5.update_layout(  
    showlegend=False,
    height=1000,
    width=1000,
)

fig5.update_xaxes(title_text='Город проживания', row=1, col=1)
fig5.update_yaxes(title_text='Медианная зарплата,руб.', row=1, col=1)
fig5.update_xaxes(tickvals=[0,1,2,3], ticktext=['Москва', 'Санкт-Петербург','город-миллионник','другие'], row=2, col=1)
fig5.update_yaxes(title_text='Медианная зарплата,руб.', row=2, col=1)
fig5.show()

# %% [markdown]
# Медианные желаемы заработные платы сильно отличаются в разных городах. Самое большое значение имеет Москва: 85тыс.руб. За ней идет Санкт-Петербург, со значением 60тыс.руб., что меньше почти на 30%. Среди городов миллионников и "других" городов медианная желаемая зарплата не отличается и составляет 40тыс.руб. При этом для этих категорий медианная зарплата меньше значения для Санкт-Петербурга на 25%.
# Из диаграммы Тьюки видно, что разброс заработной платы тоже отличается для Санкт-Петербурга, он больше, чем для городов-миллионников и других городов в выборке. Для Москвы он превышает разброс для Санкт-Петербурга в разы.
# Из приведенных графиков видно, что город проживания может стать очень важным фактором при прогнозировании зарплаты.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
#Так как это явно не указано в задании, не фильтруем желаемую зарпату до 1 млн.руб. 

fig6 = px.bar(
    data_frame=df.groupby(['Готовность к переезду','Готовность к командировкам'],as_index=False).agg({'ЗП (руб)':'median',}), 
    x="Готовность к переезду", 
    y="ЗП (руб)", 
    color="Готовность к командировкам",
    labels={'ЗП (руб)': 'Медианная ЗП(руб)', },
    orientation='v',
    barmode='overlay',
    height=500, 
    width=1100, 
    category_orders={'Готовность к командировкам': [True, False]},
    title='Медианная желаемая зарплата в зависимости от готовности к перезду и командировакам'
)

fig6.update_layout(
    showlegend=True,
    title_x=0.5,
    font_size=14,
    title_font_size=20
)

fig6.update_traces(name='Готовы', selector=dict(name='True'))
fig6.update_traces(name='Не готовы', selector=dict(name='False'))
fig6.update_xaxes(tickvals=[0,1], ticktext=['Не готовы', 'Готовы'])
fig6.show()

# %% [markdown]
# Из графика видна четкая зависимость медианы желаемой зарплаты от мобильности соискателя.
# Не готовые к переезду и командировкам запрашивают, в среднем, меньше.
# Интересно, что готовность к командировкам ведет к большей медианной зарплате чем просто переезд. Скорее всего это связано с достаточной мобильностью работника при командировке, а вот полный переезд может быть сопряжен с проблемами для работодателя.
# Как и ожидалось, самая высокая медианная желаемая зарплата у соискателей, готовых и к переезду, и к командировкам. Стоит отметить, что готовность к переезду в дополнении к готовности к командировки дает не большой прирост медианы зарплаты.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
#При построении откинем аномальное значение со 100 летним кандидатом
df_age_edu = df[df['Возраст']<80].pivot_table(
    values='ЗП (руб)',
    index='Возраст',
    columns='Образование',
    aggfunc='median',
    fill_value=np.nan
)

fig7 = px.imshow(
    df_age_edu,
    color_continuous_scale='RdYlGn_r',
    title='Зависимость желаемой медианной зарплаты от возраста и образования соискателей',
    height=800, 
    width=1000,
    labels=dict(
        x='Образование',
        y='Возраст',
        color='Медианная ЗП'
    )
)

fig7.update_layout(title_x=0.5)   
fig7.show()

# %% [markdown]
# Из тепловой карты видно тренды роста желаемой медианы зарплаты от возраста соискателей в разрезе уровня образования. Самый быстрый рост показывает группа с высшим образованием, в группе есть много кандидатов пожилого возраста, высокую медиана можно объяснить значительным опытом данных кандидатов.
# Группа не оконченного высшего образования показывает чуть меньшую скорость роста, но рост по прежнему четко прослеживается.
# Для групп со средним и среднеспециальным образованием тренд роста не большой.
# Как мы определили, запись для возраста в 100 лет является ошибочной и подлежит исключению. (на графике не отображается)

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %% [markdown]
# Введем временный признак опыта в годах, при построении обрежем график на 80 годах, так как значение 100 лет является выбросом и график становится более читаемым.

# %%
df['Опыт работы (лет)'] = df['Опыт работы (месяц)'] / 12
fig8 = go.Figure()
fig8.add_trace(go.Scatter(
    x=df['Возраст'],
    y=df['Опыт работы (лет)'],
    mode='markers',
    marker=dict(color='red', size=5, opacity=0.5),
    showlegend=False
    )
)

fig8.update_layout(  
    showlegend=True,
    height=600,
    width=1000,
)

x_line = np.linspace(0, 100, 100)
y_line = x_line
fig8.add_trace(go.Scatter(x=x_line, y=y_line, mode='lines', name='Возраст = Опыту', line=dict(dash='dash', color='blue')))

x_line = np.linspace(14, 100, 100)
y_line = x_line -14
fig8.add_trace(go.Scatter(x=x_line, y=y_line, mode='lines', name='Возраст-14 лет  = Опыту', line=dict(dash='dash', color='green')))

fig8.update_layout(title='Диаграмма рассеяния опыта работы в зависимости от возраста', xaxis_title='Возраст(лет)', yaxis_title='Опыт работы(лет)',title_x=0.5,)
fig8.update_yaxes(range=[0, 100])
fig8.update_xaxes(range=[0, 80])
fig8.show()
df.drop('Опыт работы (лет)',axis=1,inplace=True)

# %% [markdown]
# На графике(с помощью масштабирования) можно найти 7 явных аномалой, кроме того, учитывая, что минимальный возраст начала трудовой деятельности(с разрешения родителей) - 14 лет, проведем вторую линию, учитывающую это. Все значения выше этой линии - потенциальные аномалии.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %% [markdown]
# В качестве дополнительного анализа оценим зависимость медианной желаемой заработной платы в зависимости от предпочитаемого графика и занятости.

# %%
busyness = ['полная занятость','частичная занятость','проектная работа','волонтерство','стажировка']
schedules = ['полный день','сменный график','гибкий график','удаленная работа','вахтовый метод']
fig9 = go.Figure()

for schedule in schedules:
    y_values = []
    for busy in busyness:
        median_salary = df[(df[schedule] == True) & (df[busy] == True)]['ЗП (руб)'].median()
        y_values.append(median_salary)
    fig9.add_trace(go.Bar(
        x=busyness,
        y=y_values,
        name=schedule,
        legendgroup=schedule,  # группировка в легенде
        showlegend=True       # показывать только первый раз
    )
)

fig9.update_layout(barmode='group', title='Медианные зарплата по занятости и графику', title_x=0.5,height=600, width=1000,)
fig9.show()

# %% [markdown]
# Признак «график работы» оказался не слишком информативным. Из диаграммы видно, что медианная желаемая заработная плата практически не отличается по категориям занятости. Уменьшение ЗП можно выделить только для сменного графика. По признаку занятости виден заметный спад ожиданий при волонтерстве и стажировке, что вполне логично. Так же можно заметить, что полная занятость и проектная деятельность, в среднем, оплачивается выше, чем частичная занятость.

# %% [markdown]
# В наших исследованиях мы совсем обошли признак пола, сравним желаемые медианные зарплаты в зависимости от образования для мужчин и женщин.

# %%
genders = {'М':'Мужчины','Ж':'Женщины'}
fig10 = go.Figure()
for gender,gname in genders.items():
    filtered = df[(df['ЗП (руб)']<1000000)&(df['Пол']==gender)]
    grouped = (
        filtered.groupby('Образование', as_index=False)
        .agg({'ЗП (руб)': 'median'})
    )
    education_unique = grouped['Образование'].unique().tolist()

    fig10.add_trace(go.Bar(
        x=grouped['Образование'],
        y=grouped['ЗП (руб)'],
        text=grouped['ЗП (руб)'].round(1).astype(str),
        textposition='auto',
        name=gname
    )
)
    
fig10.update_layout(  
    height=800,
    width=1000)    
fig10.show()

# %% [markdown]
# Как видно, зависимость медианной зарплаты от образования совпадает с ранее полученной для каждого пола. Однако стоит заметить, что зарплатные ожидания женщин ниже мужских на 20-30%, такие образом, пол кандидата можно считать существенным признаком при прогнозировании заработной платы.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
mask = df.duplicated(subset=df)
df_dup = df[mask]
print(f'Число найденных дубликатов: {df_dup.shape[0]}')
dupl_columns = list(df.columns)
df = df.drop_duplicates(subset=dupl_columns)
# Out:
# Число найденных дубликатов: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
df.isnull().mean()
# Out:
# Ищет работу на должность:          0.000000
# Последнее/нынешнее место работы    0.000022
# Последняя/нынешняя должность       0.000045
# Обновление резюме                  0.000000
# Авто                               0.000000
# Образование                        0.000000
# Пол                                0.000000
# Возраст                            0.000000
# Опыт работы (месяц)                0.003768
# Город                              0.000000
# Готовность к переезду              0.000000
# Готовность к командировкам         0.000000
# полная занятость                   0.000000
# частичная занятость                0.000000
# проектная работа                   0.000000
# волонтерство                       0.000000
# стажировка                         0.000000
# полный день                        0.000000
# сменный график                     0.000000
# гибкий график                      0.000000
# удаленная работа                   0.000000
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
df = df.dropna(subset=['Последнее/нынешнее место работы','Последняя/нынешняя должность'], axis=0)
values = {
    'Опыт работы (месяц)': df['Опыт работы (месяц)'].median(),
}
df = df.fillna(values)
print(f'Результирующее среднее значение в столбце «Опыт работы (месяц)» после заполнения пропусков: {df['Опыт работы (месяц)'].mean():.0f}')
# Out:
# Результирующее среднее значение в столбце «Опыт работы (месяц)» после заполнения пропусков: 114

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
mask2 = (df['ЗП (руб)']>1000000) | (df['ЗП (руб)']<1000)
df = df[~mask2]
print(f'Количество резюме с ЗП больше 1 млн.руб. или меньше 1 тыс.руб: {mask2.value_counts().get(True, 0)}')
# Out:
# Количество резюме с ЗП больше 1 млн.руб. или меньше 1 тыс.руб: 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
df['Опыт работы (лет)'] = df['Опыт работы (месяц)'] / 12
mask3 = (df['Опыт работы (лет)'] > df['Возраст'])
df = df[~mask3]
print(f'Количество резюме с опытом работы больше возраста: {mask3.value_counts().get(True, 0)}')
# Out:
# Количество резюме с опытом работы больше возраста: 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_age = np.log(df['Возраст'])
histplot = sns.histplot(log_age, bins=30, ax=ax)
histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(log_age.mean() + 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean() - 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Распределение возраста (логарифмический масштаб) с границами интервала z-отклонений');

def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=3):
    if log_scale:
        x = np.log(data[feature])
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned
print(f'Тип асимметрии: {'Правосторонняя' if log_age.skew() > 0 else 'Левосторонняя'}')
outliers, cleaned = outliers_z_score_mod(
    df, 'Возраст', log_scale=True, left=3, right=4)
df = df.drop(outliers.index,axis=0)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Выбросы возраста по методу z-отклонения: {outliers['Возраст']}')
# Out:
# Тип асимметрии: Правосторонняя
# Число выбросов по методу z-отклонения: 3

# %% [markdown]
# При визуализации признака "Возраст" в логарифмическом масштабе можно видеть нормальное распределение с правосторонней асимметрией (значит изначальное распределение было близко к логнормальному). При определении выбросов методом z-отклонения с послаблением на 1 сигму с правой стороны, в выбросы попали значения 100 лет и 15 лет.
